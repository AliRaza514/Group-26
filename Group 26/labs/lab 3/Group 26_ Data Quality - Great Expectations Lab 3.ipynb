# %%
pip install great_expectations
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: great_expectations in c:\users\hp pro\appdata\roaming\python\python312\site-packages (1.3.7)
# Requirement already satisfied: altair<5.0.0,>=4.2.1 in c:\users\hp pro\appdata\roaming\python\python312\site-packages (from great_expectations) (4.2.2)
# Requirement already satisfied: cryptography>=3.2 in c:\anaconda3\lib\site-packages (from great_expectations) (42.0.5)
# Requirement already satisfied: jinja2>=3 in c:\anaconda3\lib\site-packages (from great_expectations) (3.1.4)
# Requirement already satisfied: jsonschema>=2.5.1 in c:\anaconda3\lib\site-packages (from great_expectations) (4.19.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in c:\users\hp pro\appdata\roaming\python\python312\site-packages (from great_expectations) (3.26.1)
# Requirement already satisfied: mistune>=0.8.4 in c:\anaconda3\lib\site-packages (from great_expectations) (2.0.4)
# Requirement already satisfied: packaging in c:\anaconda3\lib\site-packages (from great_expectations) (23.2)
# Requirement already satisfied: posthog<4,>3 in c:\users\hp pro\appdata\roaming\python\python312\site-packages (from great_expectations) (3.15.1)
# Requirement already satisfied: pydantic>=1.10.7 in c:\anaconda3\lib\site-packages (from great_expectations) (2.5.3)
# Requirement already satisfied: pyparsing>=2.4 in c:\anaconda3\lib\site-packages (from great_expectations) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\anaconda3\lib\site-packages (from great_expectations) (2.9.0.post0)
# Requirement already satisfied: requests>=2.20 in c:\anaconda3\lib\site-packages (from great_expectations) (2.32.2)
# Requirement already satisfied: ruamel.yaml>=0.16 in c:\anaconda3\lib\site-packages (from great_expectations) (0.17.21)
# Requirement already satisfied: scipy>=1.6.0 in c:\anaconda3\lib\site-packages (from great_expectations) (1.13.1)
# Requirement already satisfied: tqdm>=4.59.0 in c:\anaconda3\lib\site-packages (from great_expectations) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\anaconda3\lib\site-packages (from great_expectations) (4.11.0)
# Requirement already satisfied: tzlocal>=1.2 in c:\users\hp pro\appdata\roaming\python\python312\site-packages (from great_expectations) (5.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\anaconda3\lib\site-packages (from great_expectations) (1.26.4)
# Requirement already satisfied: pandas<2.2,>=1.3.0 in c:\users\hp pro\appdata\roaming\python\python312\site-packages (from great_expectations) (2.1.4)
# Requirement already satisfied: entrypoints in c:\anaconda3\lib\site-packages (from altair<5.0.0,>=4.2.1->great_expectations) (0.4)
# Requirement already satisfied: toolz in c:\anaconda3\lib\site-packages (from altair<5.0.0,>=4.2.1->great_expectations) (0.12.0)
# Requirement already satisfied: cffi>=1.12 in c:\anaconda3\lib\site-packages (from cryptography>=3.2->great_expectations) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda3\lib\site-packages (from jinja2>=3->great_expectations) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (0.10.6)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda3\lib\site-packages (from pandas<2.2,>=1.3.0->great_expectations) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\anaconda3\lib\site-packages (from pandas<2.2,>=1.3.0->great_expectations) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from posthog<4,>3->great_expectations) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in c:\users\hp pro\appdata\roaming\python\python312\site-packages (from posthog<4,>3->great_expectations) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\hp pro\appdata\roaming\python\python312\site-packages (from posthog<4,>3->great_expectations) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\anaconda3\lib\site-packages (from pydantic>=1.10.7->great_expectations) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\anaconda3\lib\site-packages (from pydantic>=1.10.7->great_expectations) (2.14.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda3\lib\site-packages (from requests>=2.20->great_expectations) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\lib\site-packages (from requests>=2.20->great_expectations) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests>=2.20->great_expectations) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests>=2.20->great_expectations) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\hp pro\appdata\roaming\python\python312\site-packages (from tqdm>=4.59.0->great_expectations) (0.4.6)
# Requirement already satisfied: pycparser in c:\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.2->great_expectations) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import great_expectations as gx
import pandas as pd

# %%
df = pd.read_csv(
    "https://raw.githubusercontent.com/great-expectations/gx_tutorials/main/data/yellow_tripdata_sample_2019-01.csv"
)
df
# Out:
#       vendor_id      pickup_datetime     dropoff_datetime  passenger_count  \
# 0             1  2019-01-15 03:36:12  2019-01-15 03:42:19                1
# 1             1  2019-01-25 18:20:32  2019-01-25 18:26:55                1
# 2             1  2019-01-05 06:47:31  2019-01-05 06:52:19                1
# 3             1  2019-01-09 15:08:02  2019-01-09 15:20:17                1
# 4             1  2019-01-25 18:49:51  2019-01-25 18:56:44                1
# ...         ...                  ...                  ...              ...
# 9995          2  2019-01-02 07:48:44  2019-01-02 08:00:13                6
# 9996          2  2019-01-16 19:06:45  2019-01-16 19:10:05                6
# 9997          2  2019-01-02 09:10:44  2019-01-02 09:36:46                6
# 9998          2  2019-01-03 13:28:36  2019-01-03 13:36:42                6
# 9999          2  2019-01-26 17:48:59  2019-01-26 18:03:01                6
#
#       trip_distance  rate_code_id store_and_fwd_flag  pickup_location_id  \
# 0              1.00             1                  N                 230
# 1              0.80             1                  N                 112
# 2              1.10             1                  N                 107
# 3              2.50             1                  N                 143
# 4              0.80             1                  N                 246
# ...             ...           ...                ...                 ...
# 9995           1.07             1                  N                  50
# 9996           0.35             1                  N                 234
# 9997           4.12             1                  N                  50
# 9998           1.17             1                  N                 137
# 9999           2.44             1                  N                 161
#
#       dropoff_location_id  payment_type  fare_amount  extra  mta_tax  \
# 0                      48             1          6.5    0.5      0.5
# 1                     112             1          6.0    1.0      0.5
# 2                       4             2          6.0    0.0      0.5
# 3                     158             1         11.0    0.0      0.5
# 4                      90             1          6.5    1.0      0.5
# ...                   ...           ...          ...    ...      ...
# 9995                  161             2          8.5    0.0      0.5
# 9996                  234             1          4.0    1.0      0.5
# 9997                  236             1         20.0    0.0      0.5
# 9998                  234             1          7.0    0.0      0.5
# 9999                  236             2         11.0    0.0      0.5
#
#       tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0           1.95           0.0                    0.3          9.75
# 1           1.55           0.0                    0.3          9.35
# 2           0.00           0.0                    0.3          6.80
# 3           3.00           0.0                    0.3         14.80
# 4           1.65           0.0                    0.3          9.95
# ...          ...           ...                    ...           ...
# 9995        0.00           0.0                    0.3          9.30
# 9996        1.16           0.0                    0.3          6.96
# 9997        6.24           0.0                    0.3         27.04
# 9998        0.90           0.0                    0.3          8.70
# 9999        0.00           0.0                    0.3         11.80
#
#       congestion_surcharge
# 0                      NaN
# 1                      0.0
# 2                      NaN
# 3                      NaN
# 4                      0.0
# ...                    ...
# 9995                   NaN
# 9996                   NaN
# 9997                   NaN
# 9998                   NaN
# 9999                   0.0
#
# [10000 rows x 18 columns]

# %% [markdown]
# # Using Great Expectations

# %%
## Example Setup

context = gx.get_context()
data_source = context.data_sources.add_pandas("pandas")
data_asset = data_source.add_dataframe_asset(name="pd dataframe asset")

batch_definition = data_asset.add_batch_definition_whole_dataframe("batch definition")
batch = batch_definition.get_batch(batch_parameters={"dataframe": df})

expectation = gx.expectations.ExpectColumnValuesToBeBetween(
    column="passenger_count", min_value=1, max_value=6
)

validation_result = batch.validate(expectation)
# Out:
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# #**To-do:**
#
# 1.   Fetch any dataset from online source. I'll recommend using reddit API used in the assignment #1.
# 2.   Run 5 expectations of your choice to validate the dataset. They should cover row, column, multi-column, table, distribution operation.
# 3.   Submit the notebook file on LMS before Monday 11:55 PM.
# 4.   Mention your group number in the name of the file.

# %%
import great_expectations as gx
import pandas as pd

# Fetch dataset
df = pd.read_csv(
    "https://raw.githubusercontent.com/great-expectations/gx_tutorials/main/data/yellow_tripdata_sample_2019-01.csv"
)

# Setup Great Expectations
context = gx.get_context()

# Create or load an expectation suite
suite_name = "my_expectation_suite"
suite = context.add_expectation_suite(suite_name)

# Create a Validator using PandasDatasource
validator = context.sources.pandas_default.read_dataframe(df)

# Define Expectations

#Row Expectation
validator.expect_table_row_count_to_be_greater_than(value=10000)  # At least 10,000 rows 

#Column Level Expectation
validator.expect_column_values_to_be_between(column="passenger_count", min_value=1, max_value=6)  #Passenger count range

# Multi-column expectation
validator.expect_multicolumn_values_to_be_ordered(column_list=["pickup_datetime", "dropoff_datetime"])  # Pickup before dropoff

# expected columns expectation
validator.expect_table_columns_to_match_set(column_set=list(df.columns))  # Ensuring expected columns exist

# distributional expectation
validator.expect_column_values_to_be_between(column="trip_distance", min_value=0.1, max_value=50)  # Trip distance range

# Save the expectation suite
context.save_expectation_suite(suite, suite_name)

# Validate the data
validation_result = validator.validate()

# Print validation results
print(validation_result)
